# %% [markdown]
# # Assignment 4
#
#
# 1. What is Object-Oriented Programming (OOP)?
#
# -> Object-Oriented Programming is a way of writing programs by using objects.
# Instead of writing everything in one place, the program is divided into small parts called objects.
#
# Each object contains data and the functions related to that data.
# This makes the code easier to understand and handle.
#
# OOP is based on real-life things like student, car, or bank account.
# Because of this, programs become more logical and structured.
#
# It also helps in reusing code and managing large programs easily.
#
# Real-life example:
# A car is an object. It has data like color and speed, and actions like start and stop.
#
# 2. What is a class in OOP?
#
# ->A class is like a blueprint used to create objects.
# It defines what data an object will have and what actions it can perform.
#
# A class does not take memory by itself.
# Memory is allocated only when an object of the class is created.
#
# All objects created from the same class share the same structure.
# This helps in keeping the program organized.
#
# Real-life example:
# A Student class can define name and roll number, and each student object will have its own values.
#
# 3. What is an object in OOP?
#
# ->An object is a real instance of a class.
# It represents a real-world entity in a program.
#
# An object contains actual data values and can use the functions of its class.
# Memory is allocated when an object is created.
#
# Multiple objects can be created from the same class, each with different data.
#
# Real-life example:
# If Student is a class, then Rohit and Amit can be objects of that class.
#
# 4. Difference between abstraction and encapsulation
#
# -> Abstraction is about showing only what is necessary and hiding the internal details.
# It focuses on what an object can do, not how it does it.
#
# Encapsulation is about wrapping data and methods together in a single unit.
# It focuses on protecting the data from direct access.
#
# Abstraction helps reduce complexity for the user.
# Encapsulation helps maintain data security and control.
#
# Example:
# Using an ATM shows abstraction (you only see options), while your account details being protected inside the system is encapsulation.
#
# 5. What are dunder methods in Python?
#
# ->Dunder methods are special methods in Python that start and end with double underscores.
# They are also called magic methods.
#
# These methods allow us to define how objects behave with built-in operations.
# Python automatically calls them when certain actions are performed.
#
# They help customize things like object creation, printing, and comparisons.
#
# Example:
# __init__ is used to initialize an object, and __str__ controls how an object is printed.
#
# 6. Explain inheritance in OOP
#
# ->Inheritance is a concept where one class gets properties and methods of another class.
# The class that inherits is called the child class, and the class being inherited from is the parent class.
#
# It helps in reusing existing code instead of writing everything again.
# Inheritance also makes programs easier to extend and manage.
#
# A child class can add its own features or modify existing ones.
#
# Real-life example:
# A Vehicle class can be a parent, and Car and Bike can inherit from it.
#
# 7. What is polymorphism in OOP?
#
# ->Polymorphism means one thing having many forms.
# It allows the same method or operation to behave differently in different situations.
#
# This helps in writing flexible and reusable code.
# The same function name can work with different objects.
#
# Polymorphism makes programs easier to extend without changing existing code.
#
# Real-life example:
# The word start can mean starting a car, a bike, or a machine, but the action is different in each case.
#
# 8. How is encapsulation achieved in Python?
#
# ->Encapsulation is done by keeping data (variables) and methods together in a class.
# Python also allows hiding data using underscores to prevent direct access.
#
# A single underscore _ means “protected” (should not be accessed directly).
#
# A double underscore __ means “private” (name gets changed internally).
#
# This way, the internal data is safe, and access is controlled through methods.
#
# Example:
# A bank account class keeps the balance private (__balance) and provides methods like deposit() and withdraw() to safely change it.
#
# 9. What is a constructor in Python?
#
# ->A constructor is a special method used to initialize an object when it is created.
#
# In Python, the constructor is called __init__().
#
# It helps set default values for the object’s attributes.
#
# The constructor runs automatically when you create an object.
#
# 10. What are class and static methods in Python?
#
# ->Class Method:
#
# A class method works with the class itself, not a particular object.
#
# It is defined using @classmethod and takes cls as the first parameter.
#
# It can access or modify class-level data.
#
# Static Method:
#
# A static method does not need the class or object to work.
#
# It is defined using @staticmethod and does not take self or cls.
#
# It’s used for utility functions that belong to the class logically.
#
# 11. What is method overloading in Python?
#
# ->Python does not support compile-time method overloading by signature.
#
# Achieve similar behavior via default args, *args/**kwargs, or @singledispatch.
#
# 12. What is method overriding in OOP?
#
# Method overriding happens when a child class provides its own version of a method defined in the parent class.
#
# This lets the child class change or extend the behavior while keeping the method name the same.
#
# 13. What is a property decorator in Python?
#
# -> @property turns a method into a getter so it can be accessed like an attribute.
#
# @<property>.setter allows controlled updating of that attribute with validation.
#
# It’s useful when you want to protect or manage private data.
#
# 14. Why is polymorphism important in OOP?
#
# -> Polymorphism allows the same code to work with different object types.
#
# It makes programs more flexible and reduces dependency between parts of the code.
#
# This helps in writing generic, reusable functions and methods.
#
# 15. What is an abstract class in Python?
#
# -> An abstract class is a class that cannot be instantiated directly.
#
# It can define abstract methods using @abstractmethod which must be implemented by subclasses.
#
# This ensures that all child classes follow a common interface.
#
# 16. Advantages of OOP
#
# -> OOP helps organize code into small, reusable units.
#
# It makes programs easier to maintain and extend.
#
# Encapsulation protects data, polymorphism allows flexibility, and inheritance promotes reuse.
#
# Overall, it helps model real-world problems in a clear way.
#
# 17. Difference between class variable and instance variable
#
# ->Class variable: shared across all objects of a class.
#
# Instance variable: unique to each object.
#
# Class variables are useful for data common to all objects, while instance variables store object-specific data.
#
# 19. What is multiple inheritance i
#
# ->A class can inherit from more than one parent class.
#
# Python uses Method Resolution Order (MRO) to decide which parent method to call if there’s a conflict.
#
# This allows a class to combine features from different classes.
#
# 19. Purpose of __str__ and __repr__
#
# ->__str__ defines a human-readable string for an object (used in print).
#
# __repr__ defines a developer-friendly representation, meant to be unambiguous.
# Both help in displaying objects clearly for different purposes.
#
# 20. Significance of super()
#
# ->super() accesses parent class methods (useful in multiple inheritance and to call parent initializers).
#
# 21. Significance of __del__
#
# ->__del__ is a finalizer called when an object is about to be destroyed — use sparingly because timing is nondeterministic (garbage collection).
#
# 22. Difference between @staticmethod and @classmethod
#
# @staticmethod does not take self or cls and is used for utility functions inside a class.
#
# @classmethod takes cls and can access or modify class-level data.
# Use class methods when behavior depends on the class, not on a specific object.
#
# 23. How does polymorphism work in Python with inheritance?
#
# When a subclass overrides a method, Python calls the version based on the object type at runtime.
#
# This is called runtime polymorphism.
#
# Duck typing in Python also allows objects to work as long as they support the required methods.
#
# 24. What is method chaining in Python OOP?
#
# Method chaining is when methods return self so multiple calls can be linked in one line.
#
# For example: obj.a().b().c().
#
# It makes code cleaner and more readable.
#
# 25. Purpose of __call__ method
#
# __call__ allows an object to be called like a function.
#
# When you do obj(), it executes the object’s __call__ method.
#
# This is useful for objects that need function-like behavior.

# %%
#1. Create a parent class Animal with a method speak() that prints a generic message.
# Create a child class Dog that overrides the speak() method to print "Bark!"
class Animal:
    def speak(self):
        print("The animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# Example:
if __name__ == "__main__":
    a = Animal(); a.speak()   # The animal makes a sound.
    d = Dog(); d.speak()     # Bark!
# Out:
# The animal makes a sound.
# Bark!

# %%
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.


from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return math.pi * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        return self.width * self.height

# Example:
if __name__ == "__main__":
    c = Circle(2); print(round(c.area(), 4))      # 12.5664...
    r = Rectangle(3, 4); print(r.area())         # 12
# Out:
# 12.5664
# 12

# %%
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.


class Vehicle:
    def __init__(self, vtype):
        self.type = vtype

class Car(Vehicle):
    def __init__(self, brand, vtype="Car"):
        super().__init__(vtype)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, brand, battery_kwh, vtype="Car"):
        super().__init__(brand, vtype)
        self.battery = battery_kwh

# Example:
if __name__ == "__main__":
    e = ElectricCar("Tesla", 75)
    print(e.brand, e.type, e.battery)  # Tesla Car 75
# Out:
# Tesla Car 75

# %%
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.


class Bird:
    def fly(self):
        print("Some birds can fly.")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high.")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly; they swim instead.")

# Example:
if __name__ == "__main__":
    birds = [Sparrow(), Penguin()]
    for b in birds:
        b.fly()
# Out:
# Sparrow flies high.
# Penguins cannot fly; they swim instead.

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.


class BankAccount:
    def __init__(self, initial=0):
        self.__balance = float(initial)  # private attribute

    def deposit(self, amount):
        if amount <= 0: raise ValueError("Deposit must be positive")
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= 0: raise ValueError("Withdraw must be positive")
        if amount > self.__balance: raise ValueError("Insufficient funds")
        self.__balance -= amount

    def get_balance(self):
        return self.__balance

# Example:
if __name__ == "__main__":
    acct = BankAccount(100)
    acct.deposit(50)
    acct.withdraw(30)
    print(acct.get_balance())  # 120.0
# Out:
# 120.0

# %%
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().


class Instrument:
    def play(self):
        raise NotImplementedError

class Guitar(Instrument):
    def play(self):
        print("Strum the guitar.")

class Piano(Instrument):
    def play(self):
        print("Play the piano keys.")

# Example:
if __name__ == "__main__":
    for instr in (Guitar(), Piano()):
        instr.play()
# Out:
# Strum the guitar.
# Play the piano keys.

# %%
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.


class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Example:
if __name__ == "__main__":
    print(MathOperations.add_numbers(3, 4))        # 7
    print(MathOperations.subtract_numbers(10, 3))  # 7
# Out:
# 7
# 7

# %%
# 8. Implement a class Person with a class method to count the total number of persons created.

class Person:
    _count = 0

    def __init__(self, name):
        self.name = name
        Person._count += 1

    @classmethod
    def total_persons(cls):
        return cls._count

# Example:
if __name__ == "__main__":
    p1 = Person("A")
    p2 = Person("B")
    print(Person.total_persons())  # 2
# Out:
# 2

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator"

class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0: raise ValueError("Denominator can't be zero")
        self.n = int(numerator)
        self.d = int(denominator)

    def __str__(self):
        return f"{self.n}/{self.d}"

    def __repr__(self):
        return f"Fraction({self.n}, {self.d})"

# Example:
if __name__ == "__main__":
    f = Fraction(3, 4)
    print(str(f))   # 3/4
    print(repr(f))  # Fraction(3, 4)
# Out:
# 3/4
# Fraction(3, 4)

# %%
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.


class Vector:
    def __init__(self, components):
        self.components = list(components)

    def __add__(self, other):
        if len(self.components) != len(other.components):
            raise ValueError("Vectors must be same length")
        return Vector([a + b for a, b in zip(self.components, other.components)])

    def __str__(self):
        return f"Vector({self.components})"

# Example:
if __name__ == "__main__":
    v1 = Vector([1,2,3])
    v2 = Vector([4,5,6])
    print((v1 + v2))  # Vector([5,7,9])
# Out:
# Vector([5, 7, 9])

# %%
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."


class PersonSimple:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example:
if __name__ == "__main__":
    p = PersonSimple("Rohit", 21)
    p.greet()
# Out:
# Hello, my name is Rohit and I am 21 years old.

# %%
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0.0
        return sum(self.grades) / len(self.grades)

# Example:
if __name__ == "__main__":
    s = Student("A", [80, 90, 75])
    print(s.average_grade())  # 81.666...
# Out:
# 81.66666666666667

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.


class Rectangle:
    def __init__(self, width=0, height=0):
        self.width = width
        self.height = height

    def set_dimensions(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Example:
if __name__ == "__main__":
    r = Rectangle()
    r.set_dimensions(4, 5)
    print(r.area())  # 20
# Out:
# 20

# %%
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus=0):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# Example:
if __name__ == "__main__":
    m = Manager("M", 40, 50, bonus=500)
    print(m.calculate_salary())
# Out:
# 2500

# %%
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.


class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = float(price)
        self.quantity = int(quantity)

    def total_price(self):
        return self.price * self.quantity

# Example:
if __name__ == "__main__":
    p = Product("Pen", 2.5, 10)
    print(p.total_price())  # 25.0
# Out:
# 25.0

# %%
# Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.


from abc import ABC, abstractmethod

class AnimalBase(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(AnimalBase):
    def sound(self):
        print("Moo")

class Sheep(AnimalBase):
    def sound(self):
        print("Baa")

# Example:
if __name__ == "__main__":
    Cow().sound(); Sheep().sound()
# Out:
# Moo
# Baa

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.


class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author} ({self.year_published})"

# Example:
if __name__ == "__main__":
    b = Book("1984", "George Orwell", 1949)
    print(b.get_book_info())
# Out:
# '1984' by George Orwell (1949)

# %%
#18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

# Example:
if __name__ == "__main__":
    m = Mansion("Hilltop", 2_000_000, 12)
    print(m.address, m.price, m.number_of_rooms)
# Out:
# Hilltop 2000000 12

# %% [markdown]
# # 📝 What I Learned
#
# How to design programs using classes and objects
#
# The importance of OOP principles in large projects
#
# How OOP improves code readability and maintainability
#
# **This assignment strengthened my understanding of structuring Python programs effectively for real-world applications.**
